# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import json


html = urlopen("https://vnexpress.net/")
bs = BeautifulSoup(html.read(), 'html.parser')

# articles = bs.findAll('article')

titles = []
images = []
description = []


for tag in  bs.findAll('article'):
    titles.append(str(tag.a["title"]))
    images.append(str(tag.img["data-original"]))
# Out:
#   File "<ipython-input-4-24a0bff78639>", line 18
#     images.append(str(tag.img["data-original"])
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
titles = []
images = []
description = []

for tag in  bs.findAll('article'):
  titles.append(tag.find(''))
  images.append(tag.findAll('img'))
  description.append(tag.findAll('p'))
    print(tag)
# Out:
# <article>
# <div class="thumb_big">
# <a class="thumb thumb_5x3" href="https://vnexpress.net/world-cup-2022/park-hang-seo-tu-nhung-chiec-ao-bi-trao-so-den-dau-bang-g-4012857.html?vn_source=Home&amp;vn_campaign=ThuongVien&amp;vn_medium=Item-1&amp;vn_term=Desktop&amp;vn_thumb=1" title="Park Hang-seo: Từ những chiếc áo bị tráo số đến đầu bảng G">
# <img alt="Park Hang-seo: Từ những chiếc áo bị tráo số đến đầu bảng G" class="vne_lazy_image" data-original="https://i-vnexpress.vnecdn.net/2019/11/15/lvt174915736508651200x0-157379-4987-6197-1573796823_500x300.jpg" src="https://i-vnexpress.vnecdn.net/2019/11/15/lvt174915736508651200x0-157379-4987-6197-1573796823_500x300.jpg"/>
# </a>
# </div>
# <h1 class="title_news">
# ...

# %%
print(titles)
# Out:
# [[<a class="thumb thumb_5x3" href="https://vnexpress.net/world-cup-2022/park-hang-seo-tu-nhung-chiec-ao-bi-trao-so-den-dau-bang-g-4012857.html?vn_source=Home&amp;vn_campaign=ThuongVien&amp;vn_medium=Item-1&amp;vn_term=Desktop&amp;vn_thumb=1" title="Park Hang-seo: Từ những chiếc áo bị tráo số đến đầu bảng G">
# <img alt="Park Hang-seo: Từ những chiếc áo bị tráo số đến đầu bảng G" class="vne_lazy_image" data-original="https://i-vnexpress.vnecdn.net/2019/11/15/lvt174915736508651200x0-157379-4987-6197-1573796823_500x300.jpg" src="https://i-vnexpress.vnecdn.net/2019/11/15/lvt174915736508651200x0-157379-4987-6197-1573796823_500x300.jpg"/>
# </a>, <a href="https://vnexpress.net/world-cup-2022/park-hang-seo-tu-nhung-chiec-ao-bi-trao-so-den-dau-bang-g-4012857.html?vn_source=Home&amp;vn_campaign=ThuongVien&amp;vn_medium=Item-1&amp;vn_term=Desktop&amp;vn_thumb=1" title="Park Hang-seo: Từ những chiếc áo bị tráo số đến đầu bảng G">
# ...
